# %% [markdown]
# # Data batch processing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import os
from scipy.stats import entropy
from concurrent.futures import ThreadPoolExecutor, as_completed
# Out:
# /Users/jasonc/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
consumer_df = pd.read_parquet("/Users/jasonc/Desktop/DSC_291/cashflow/consumer_data.parquet")

# %%
consumer_df
# Out:
#      evaluation_date  FPF_TARGET  total_balance masked_consumer_id
# 0         2021-08-26         0.0        1380.84          C01100001
# 1         2022-08-02         0.0       20163.90          C01100002
# 2         2021-03-04         0.0        3986.25          C01100003
# 3         2022-11-19         0.0        5956.03          C01100004
# 4         2021-11-21         0.0       29421.10          C01100005
# ...              ...         ...            ...                ...
# 4995      2023-03-31         0.0        1412.80          C04104996
# 4996      2023-03-31         0.0        -439.21          C04104997
# 4997      2023-03-31         0.0          84.53          C04104998
# 4998      2023-03-31         0.0       52655.88          C04104999
# 4999      2023-03-31         0.0       40004.69          C04105000
#
# [16000 rows x 4 columns]

# %%
# FFT Feature Function
def extract_fft_features(ts, detrend=True, low_freq_cut=0.05, high_freq_cut=0.25):
    ts = ts.asfreq('W-MON').fillna(0)
    if detrend:
        ts = ts - ts.mean()

    fft_vals = np.fft.fft(ts)
    fft_freqs = np.fft.fftfreq(len(ts), d=1)
    pos_mask = fft_freqs > 0
    freqs = fft_freqs[pos_mask]
    mags = np.abs(fft_vals)[pos_mask]
    power = mags**2
    power_norm = power / power.sum()

    if len(power) == 0:
        return None

    dominant_idx = np.argmax(power)
    dominant_freq = freqs[dominant_idx]
    dominant_power = power[dominant_idx]
    spectral_entropy = entropy(power_norm)
    low_power = power[freqs < low_freq_cut].sum()
    high_power = power[freqs > high_freq_cut].sum()
    power_ratio = low_power / (high_power + 1e-6)

    return {
        "dominant_freq": dominant_freq,
        "dominant_power": dominant_power,
        "spectral_entropy": spectral_entropy,
        "low_freq_power": low_power,
        "high_freq_power": high_power,
        "power_ratio": power_ratio
    }

# %%
def weekly_trimmed(ts):
    ts = ts.groupby(ts.index).sum()  # collapse duplicates
    ts = ts.asfreq('D').fillna(0)
    if ts.empty:
        return pd.Series(dtype=float)

    first_monday = ts.index[0] + pd.DateOffset(days=(7 - ts.index[0].weekday()) % 7)
    last_sunday = ts.index[-1] - pd.DateOffset(days=(ts.index[-1].weekday() + 1) % 7)
    ts_trimmed = ts[(ts.index >= first_monday) & (ts.index <= last_sunday)]

    return ts_trimmed.resample('W-MON').sum()

# %%
# Consumer Processor
def process_consumer_file(file_path):
    try:
        consumer_id = os.path.basename(file_path).replace(".parquet", "")
        df = pd.read_parquet(file_path)

        # Safely convert to datetime
        df['posted_date'] = pd.to_datetime(df['posted_date'], errors='coerce')
        df = df.dropna(subset=['posted_date'])
        df = df.sort_values('posted_date')

        if df.empty:
            raise ValueError("No valid posted_date after cleaning")

        # Resample to daily and fill forward
        ts = (
            df.set_index('posted_date')
            .resample('D')['amount']
            .sum()
            .ffill()
        )

        if ts.empty or ts.sum() == 0 or ts.std() == 0:
            raise ValueError("Time series is empty or flat")

        features = extract_fft_features(ts)
        if features is None:
            raise ValueError("FFT failed due to empty power spectrum")

        features['masked_consumer_id'] = consumer_id
        print(f"✓ Processed {consumer_id}")
        return features

    except Exception as e:
        print(f"✗ Failed {file_path}: {e}")
        return None

# %%
def process_consumer_file_by_category(file_path, consumer_df, n_simulations=20):
    """
    Reads a single consumer's transaction Parquet file, computes FFT-based features for each category,
    and if the consumer's FPF_TARGET is 1, generates `n_simulations` noisy augmentations.

    Returns a list of feature dicts (one per real or simulated consumer)."""
    consumer_id = os.path.basename(file_path).replace(".parquet", "")
    match = consumer_df[consumer_df["masked_consumer_id"] == consumer_id]
    if match.empty:
        raise ValueError(f"Consumer ID {consumer_id} not found in metadata.")

    target_value = match["FPF_TARGET"].iloc[0]
    is_target = (target_value == 1.0)

    # Load and clean
    df = pd.read_parquet(file_path)
    df['posted_date'] = pd.to_datetime(df['posted_date'], errors='coerce')
    df = df.dropna(subset=['posted_date']).sort_values('posted_date')
    if df.empty:
        raise ValueError(f"No valid posted_date for consumer {consumer_id}")

    results = []
    ts_by_category = {}

    # Process real data per category
    for cat, sub_df in df.groupby('category'):
        ts = sub_df.set_index('posted_date')['amount']
        ts_weekly = weekly_trimmed(ts)

        # Skip invalid series
        if ts_weekly.empty or ts_weekly.sum() == 0 or len(ts_weekly) < 6:
            continue

        ts_by_category[cat] = ts_weekly
        feats = extract_fft_features(ts_weekly)
        if feats is None:
            continue

        feat_dict = {f"{k}_cat{cat}": v for k, v in feats.items()}
        feat_dict['masked_consumer_id'] = consumer_id
        feat_dict['FPF_TARGET'] = target_value
        results.append(feat_dict)

    real_count = len(results)

    # Simulations for target consumers
    sim_count = 0
    if is_target and ts_by_category:
        for sim_idx in range(1, n_simulations + 1):
            sim_id = f"{consumer_id}_simulate_{sim_idx}"
            sim_feats = {}
            # generate features across all categories
            for cat, ts_weekly in ts_by_category.items():
                noise = np.random.normal(loc=0,
                                         scale=ts_weekly.std() * 0.1,
                                         size=len(ts_weekly))
                ts_noisy = ts_weekly + noise
                feats = extract_fft_features(ts_noisy)
                if feats is None:
                    continue
                for k, v in feats.items():
                    sim_feats[f"{k}_cat{cat}"] = v

            # attach metadata
            sim_feats['masked_consumer_id'] = sim_id
            sim_feats['FPF_TARGET'] = target_value
            results.append(sim_feats)
            sim_count += 1

    if not results:
        raise ValueError(f"No valid features generated for consumer {consumer_id}")

    # Log processing summary
    if sim_count > 0:
        print(f"Processed {consumer_id}: {real_count} real entries and {sim_count} simulations (FPF_TARGET={target_value}).")
    else:
        print(f"Processed {consumer_id}: {real_count} real entries (FPF_TARGET={target_value}).")

    return results

# %%
def batch_process(tx_dir, consumer_df, n_simulations=20, max_workers=None):
    """
    Processes all consumer files in parallel, flattening real and simulated feature dicts
    into a single DataFrame."""
    file_paths = [os.path.join(tx_dir, f) for f in os.listdir(tx_dir) if f.endswith('.parquet')]
    all_dicts = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(
                process_consumer_file_by_category,
                fp,
                consumer_df,
                n_simulations
            ): fp for fp in file_paths
        }
        for future in as_completed(futures):
            path = futures[future]
            try:
                res = future.result()
                # flatten list of dicts
                all_dicts.extend(res if isinstance(res, list) else [res])
            except Exception as e:
                print(f"Error processing {path}: {e}")

    return pd.DataFrame(all_dicts)

# %%
if __name__ == "__main__":
    TX_DIR = "/Users/jasonc/Desktop/DSC_291/split_transactions"

    # Run batch processing with simulations for target consumers
    output_df = batch_process(
        TX_DIR,
        consumer_df,
        n_simulations=20,
        max_workers=None
    )

    # Save the engineered feature matrix
    output_df.sort_index(axis=1).to_csv(
        "/Users/jasonc/Desktop/DSC_291/processed_data.csv",
        index=False
    )
# Out:
# Error processing /Users/jasonc/Desktop/DSC_291/split_transactions/C03104720.parquet: No valid features generated for consumer C03104720
# Processed C03104658: 13 real entries (FPF_TARGET=0.0).
# Processed C02104921: 16 real entries (FPF_TARGET=0.0).
# Processed C03100574: 15 real entries (FPF_TARGET=0.0).
# Processed C03103766: 15 real entries (FPF_TARGET=0.0).
# Processed C03102314: 12 real entries (FPF_TARGET=0.0).
# Processed C04103556: 17 real entries (FPF_TARGET=0.0).
# Processed C04104510: 26 real entries (FPF_TARGET=0.0).
# Processed C04104468: 10 real entries (FPF_TARGET=0.0).
# Error processing /Users/jasonc/Desktop/DSC_291/split_transactions/C03101106.parquet: No valid posted_date for consumer C03101106
# Processed C04101336: 14 real entries (FPF_TARGET=0.0).
# Processed C02100394: 15 real entries (FPF_TARGET=0.0).
# Processed C02103186: 24 real entries (FPF_TARGET=0.0).
# Processed C04102124: 18 real entries (FPF_TARGET=0.0).
# ...

# %%
output_df
# Out:
#         dominant_freq_cat0.0  dominant_power_cat0.0  spectral_entropy_cat0.0  \
# 0                   0.125000           3.854318e+05                 1.052376
# 1                        NaN                    NaN                      NaN
# 2                        NaN                    NaN                      NaN
# 3                        NaN                    NaN                      NaN
# 4                        NaN                    NaN                      NaN
# ...                      ...                    ...                      ...
# 320480              0.044444           1.097864e+08                 2.626234
# 320481              0.044444           1.157732e+08                 2.546525
# 320482              0.044444           1.110504e+08                 2.584032
# 320483              0.044444           1.158226e+08                 2.525013
# 320484              0.044444           1.095160e+08                 2.586120
#
# ...

# %%
# Sort by FPF_TARGET and set masked_consumer_id as the index
output_df_sorted = output_df.sort_values(by='FPF_TARGET')
output_df_sorted = output_df_sorted[sorted(output_df_sorted.columns)]

# %%
output_df_sorted = output_df_sorted.fillna(0)
output_df_sorted = output_df_sorted.set_index('masked_consumer_id')
output_df_sorted.to_csv("/Users/jasonc/Desktop/DSC_291/processed_data.csv")

# %%
output_df_sorted
# Out:
#                        FPF_TARGET  dominant_freq_cat0.0  dominant_freq_cat1.0  \
# masked_consumer_id
# C03104658                     0.0              0.125000              0.000000
# C03100527                     0.0              0.000000              0.000000
# C03100527                     0.0              0.000000              0.000000
# C03100527                     0.0              0.000000              0.000000
# C03100527                     0.0              0.000000              0.000000
# ...                           ...                   ...                   ...
# C02103537_simulate_14         1.0              0.142857              0.086957
# C02103537_simulate_13         1.0              0.428571              0.130435
# C02103537_simulate_12         1.0              0.476190              0.086957
# C02103537_simulate_10         1.0              0.142857              0.130435
# C04101672_simulate_20         1.0              0.044444              0.020833
#
# ...

# %%
# Group by customer_category and FPF_TARGET, then count occurrences
category_target_counts = (
    output_df_sorted["FPF_TARGET"].value_counts()
)

# %%
category_target_counts
# Out:
# 0.0    234575
# 1.0     85910
# Name: FPF_TARGET, dtype: int64
