# %%
import pandas as pd

# %%
df = pd.read_parquet("/Users/jasonc/Desktop/DSC_291/merged_features.parquet")

# %%
df
# Out:
#                    evaluation_date  FPF_TARGET  total_balance  \
# masked_consumer_id
# C01100001               2021-08-26         0.0        1380.84
# C01100002               2022-08-02         0.0       20163.90
# C01100003               2021-03-04         0.0        3986.25
# C01100004               2022-11-19         0.0        5956.03
# C01100005               2021-11-21         0.0       29421.10
# ...                            ...         ...            ...
# C01104996               2023-02-01         0.0       48582.14
# C01104997               2021-07-15         0.0       11567.65
# C01104998               2021-11-08         0.0        1135.38
# C01104999               2021-09-20         0.0        4987.83
# C01105000               2023-03-14         0.0        1634.01
#
#                     dominant_freq_cat0.0  dominant_power_cat0.0  \
# masked_consumer_id
# C01100001                       0.078431           2.006075e+09
# ...

# %%
df.columns.to_list()
# Out:
# ['evaluation_date',
#  'FPF_TARGET',
#  'total_balance',
#  'dominant_freq_cat0.0',
#  'dominant_power_cat0.0',
#  'spectral_entropy_cat0.0',
#  'low_freq_power_cat0.0',
#  'high_freq_power_cat0.0',
#  'power_ratio_cat0.0',
#  'dominant_freq_cat1.0',
#  'dominant_power_cat1.0',
#  'spectral_entropy_cat1.0',
#  'low_freq_power_cat1.0',
#  'high_freq_power_cat1.0',
#  'power_ratio_cat1.0',
#  'dominant_freq_cat2.0',
#  'dominant_power_cat2.0',
#  'spectral_entropy_cat2.0',
#  'low_freq_power_cat2.0',
#  'high_freq_power_cat2.0',
#  'power_ratio_cat2.0',
#  'dominant_freq_cat3.0',
#  'dominant_power_cat3.0',
#  'spectral_entropy_cat3.0',
#  'low_freq_power_cat3.0',
#  'high_freq_power_cat3.0',
#  'power_ratio_cat3.0',
#  'dominant_freq_cat4.0',
#  'dominant_power_cat4.0',
#  'spectral_entropy_cat4.0',
#  'low_freq_power_cat4.0',
#  'high_freq_power_cat4.0',
#  'power_ratio_cat4.0',
#  'dominant_freq_cat5.0',
#  'dominant_power_cat5.0',
#  'spectral_entropy_cat5.0',
# ...
